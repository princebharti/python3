# %% [markdown]
# ### timeseries

# %%
import pandas as pd
ts=pd.read_csv('/Users/Prince.Bharti/python_files/data/excel')

# %%
ts
# Out:
#      Symbol        Date     Open       High      Low    Close    Volume  \
# 0         A  10/06/2009    27.17      27.47    26.92    27.22   2887300
# 1        AA  10/06/2009    13.82      14.02    13.64    13.89  40920300
# 2       AAC  10/06/2009     0.51       0.53     0.51     0.51      3300
# 3      AACC  10/06/2009     7.36       7.42     7.10     7.21     22100
# 4       AAI  10/06/2009     6.12       6.24     6.06     6.14   2576700
# 5      AAME  10/06/2009     1.10       1.17     1.06     1.15     86100
# 6       AAN  10/06/2009    26.41      26.88    26.24    26.59    343700
# 7     AAN.A  10/06/2009    20.86      20.88    20.86    20.88       400
# 8      AAON  10/06/2009    19.05      19.09    18.71    18.97     88700
# 9       AAP  10/06/2009    37.94      38.68    37.74    38.60   3566700
# 10     AAPL  10/06/2009   187.74     190.01   187.30   190.01  21610100
# 11      AAR  10/06/2009    18.14      18.44    18.14    18.35     16400
# ...

# %%
ts.head()
# Out:
#   Symbol        Date   Open   High    Low  Close    Volume Exchange  \
# 0      A  10/06/2009  27.17  27.47  26.92  27.22   2887300        N
# 1     AA  10/06/2009  13.82  14.02  13.64  13.89  40920300        N
# 2    AAC  10/06/2009   0.51   0.53   0.51   0.51      3300        A
# 3   AACC  10/06/2009   7.36   7.42   7.10   7.21     22100        Q
# 4    AAI  10/06/2009   6.12   6.24   6.06   6.14   2576700        N
#
#    Total Revenues  Depreciation & Amort       ...         Profit Margin  \
# 0         4795.00                201.00       ...                  3.65
# 1        21269.00               1234.00       ...                 -8.76
# 2            2.34                  0.13       ...               -110.26
# 3          219.42                  3.95       ...                  5.59
# 4         2408.31                 68.66       ...                 -4.91
#
#    Return on Equity  Return on Assets  P/E Ratio Price/Book Debt Equity  \
# ...

# %%
ts.tail()
# Out:
#      Symbol        Date     Open       High      Low    Close   Volume  \
# 7452  ZVZZT  10/06/2009   281.80  199017.70    20.00   530.30  2142000
# 7453  ZWZZT  10/06/2009    20.00      30.00     0.01     0.01    21700
# 7454  ZXZZT  10/06/2009  1000.50    2106.35  1000.50  2106.24   110700
# 7455     ZZ  10/06/2009     3.05       3.17     3.00     3.12  1463400
# 7456    ZZC  10/06/2009    81.00      83.50    80.50    81.50    12900
#
#      Exchange  Total Revenues  Depreciation & Amort       ...         \
# 7452        Q            0.00                   NaN       ...
# 7453        Q            0.00                   NaN       ...
# 7454        Q            0.00                   NaN       ...
# 7455        N         1283.76                 64.69       ...
# 7456        N            0.00                   NaN       ...
#
#       Profit Margin  Return on Equity  Return on Assets  P/E Ratio Price/Book  \
# ...

# %%
ts.head(20)
# Out:
#    Symbol        Date    Open    High     Low   Close    Volume Exchange  \
# 0       A  10/06/2009   27.17   27.47   26.92   27.22   2887300        N
# 1      AA  10/06/2009   13.82   14.02   13.64   13.89  40920300        N
# 2     AAC  10/06/2009    0.51    0.53    0.51    0.51      3300        A
# 3    AACC  10/06/2009    7.36    7.42    7.10    7.21     22100        Q
# 4     AAI  10/06/2009    6.12    6.24    6.06    6.14   2576700        N
# 5    AAME  10/06/2009    1.10    1.17    1.06    1.15     86100        Q
# 6     AAN  10/06/2009   26.41   26.88   26.24   26.59    343700        N
# 7   AAN.A  10/06/2009   20.86   20.88   20.86   20.88       400        N
# 8    AAON  10/06/2009   19.05   19.09   18.71   18.97     88700        Q
# 9     AAP  10/06/2009   37.94   38.68   37.74   38.60   3566700        N
# 10   AAPL  10/06/2009  187.74  190.01  187.30  190.01  21610100        Q
# 11    AAR  10/06/2009   18.14   18.44   18.14   18.35     16400        N
# ...

# %%
ts.tail(20)
# Out:
#      Symbol        Date     Open       High      Low    Close   Volume  \
# 7437   ZIXI  10/06/2009     2.11       2.18     2.01     2.14   329900
# 7438    ZLC  10/06/2009     6.61       6.91     6.46     6.64   473800
# 7439    ZMH  10/06/2009    50.61      51.52    49.14    51.45  4514400
# 7440     ZN  10/06/2009     9.34       9.50     9.23     9.46    43400
# 7441    ZNH  10/06/2009    15.83      15.92    15.71    15.82    15600
# 7442    ZNT  10/06/2009    31.53      31.78    31.33    31.71   253900
# 7443   ZOLL  10/06/2009    22.89      23.05    22.47    22.90   129700
# 7444   ZOLT  10/06/2009    10.47      10.75    10.30    10.55    97200
# 7445  ZOOMD  10/06/2009     7.25       7.31     6.84     7.13    61900
# 7446    ZQK  10/06/2009     2.58       2.65     2.47     2.52   831200
# 7447   ZRAN  10/06/2009    10.77      11.08    10.70    11.06   445100
# 7448   ZRBA  10/06/2009     4.77       4.95     4.77     4.91     3200
# ...

# %%
ts.index.name='sno'

# %%
ts.head()
# Out:
#     Symbol        Date   Open   High    Low  Close    Volume Exchange  \
# sno
# 0        A  10/06/2009  27.17  27.47  26.92  27.22   2887300        N
# 1       AA  10/06/2009  13.82  14.02  13.64  13.89  40920300        N
# 2      AAC  10/06/2009   0.51   0.53   0.51   0.51      3300        A
# 3     AACC  10/06/2009   7.36   7.42   7.10   7.21     22100        Q
# 4      AAI  10/06/2009   6.12   6.24   6.06   6.14   2576700        N
#
#      Total Revenues  Depreciation & Amort       ...         Profit Margin  \
# sno                                             ...
# 0           4795.00                201.00       ...                  3.65
# 1          21269.00               1234.00       ...                 -8.76
# 2              2.34                  0.13       ...               -110.26
# 3            219.42                  3.95       ...                  5.59
# 4           2408.31                 68.66       ...                 -4.91
#
# ...

# %%
ls=pd.date_range('10/06/2009',periods=7457,freq='t')

ts.index=ls
ts.head()
# Out:
#                     Symbol        Date   Open   High    Low  Close    Volume  \
# 2009-10-06 00:00:00      A  10/06/2009  27.17  27.47  26.92  27.22   2887300
# 2009-10-06 00:01:00     AA  10/06/2009  13.82  14.02  13.64  13.89  40920300
# 2009-10-06 00:02:00    AAC  10/06/2009   0.51   0.53   0.51   0.51      3300
# 2009-10-06 00:03:00   AACC  10/06/2009   7.36   7.42   7.10   7.21     22100
# 2009-10-06 00:04:00    AAI  10/06/2009   6.12   6.24   6.06   6.14   2576700
#
#                     Exchange  Total Revenues  Depreciation & Amort  \
# 2009-10-06 00:00:00        N         4795.00                201.00
# 2009-10-06 00:01:00        N        21269.00               1234.00
# 2009-10-06 00:02:00        A            2.34                  0.13
# 2009-10-06 00:03:00        Q          219.42                  3.95
# 2009-10-06 00:04:00        N         2408.31                 68.66
#
#                           ...         Profit Margin  Return on Equity  \
# ...

# %%
del ts['Low']

# %%
ts.index.name='date'
ts
# Out:
#                     Symbol        Date     Open       High    Close    Volume  \
# date
# 2009-10-06 00:00:00      A  10/06/2009    27.17      27.47    27.22   2887300
# 2009-10-06 00:01:00     AA  10/06/2009    13.82      14.02    13.89  40920300
# 2009-10-06 00:02:00    AAC  10/06/2009     0.51       0.53     0.51      3300
# 2009-10-06 00:03:00   AACC  10/06/2009     7.36       7.42     7.21     22100
# 2009-10-06 00:04:00    AAI  10/06/2009     6.12       6.24     6.14   2576700
# 2009-10-06 00:05:00   AAME  10/06/2009     1.10       1.17     1.15     86100
# 2009-10-06 00:06:00    AAN  10/06/2009    26.41      26.88    26.59    343700
# 2009-10-06 00:07:00  AAN.A  10/06/2009    20.86      20.88    20.88       400
# 2009-10-06 00:08:00   AAON  10/06/2009    19.05      19.09    18.97     88700
# 2009-10-06 00:09:00    AAP  10/06/2009    37.94      38.68    38.60   3566700
# 2009-10-06 00:10:00   AAPL  10/06/2009   187.74     190.01   190.01  21610100
# ...

# %%
type(ts)
# Out:
# pandas.core.frame.DataFrame

# %%
type(ts.index[0])
# Out:
# pandas.tslib.Timestamp

# %% [markdown]
# ### indexing of time series

# %%
ts.ix['2009-10-06 00:00:00':'2009-10-07  01:00:00']
# Out:
#                     Symbol        Date    Open    High   Close    Volume  \
# date
# 2009-10-06 00:00:00      A  10/06/2009   27.17   27.47   27.22   2887300
# 2009-10-06 00:01:00     AA  10/06/2009   13.82   14.02   13.89  40920300
# 2009-10-06 00:02:00    AAC  10/06/2009    0.51    0.53    0.51      3300
# 2009-10-06 00:03:00   AACC  10/06/2009    7.36    7.42    7.21     22100
# 2009-10-06 00:04:00    AAI  10/06/2009    6.12    6.24    6.14   2576700
# 2009-10-06 00:05:00   AAME  10/06/2009    1.10    1.17    1.15     86100
# 2009-10-06 00:06:00    AAN  10/06/2009   26.41   26.88   26.59    343700
# 2009-10-06 00:07:00  AAN.A  10/06/2009   20.86   20.88   20.88       400
# 2009-10-06 00:08:00   AAON  10/06/2009   19.05   19.09   18.97     88700
# 2009-10-06 00:09:00    AAP  10/06/2009   37.94   38.68   38.60   3566700
# 2009-10-06 00:10:00   AAPL  10/06/2009  187.74  190.01  190.01  21610100
# 2009-10-06 00:11:00    AAR  10/06/2009   18.14   18.44   18.35     16400
# ...

# %%
pd.datetime.now()
# Out:
# datetime.datetime(2016, 11, 8, 17, 8, 16, 993645)

# %% [markdown]
# ### Resampling

# %%
resampled=ts.resample('30t',how=['count','mean','median'],label='left',closed='right')
resampled
# Out:
# /Users/Prince.Bharti/anaconda/lib/python3.5/site-packages/ipykernel/__main__.py:1: FutureWarning: how in .resample() is deprecated
# the new syntax is .resample(...)..apply(<func>)
#   if __name__ == '__main__':
#                      Open                       High                        \
#                     count         mean  median count          mean  median
# date
# 2009-10-06 00:00:00    30    22.466333  18.595    30     22.828333  18.765
# 2009-10-06 00:30:00    30    21.765000   9.175    30     22.266333   9.325
# 2009-10-06 01:00:00    30    21.235000  17.450    30     21.637000  17.685
# 2009-10-06 01:30:00    30    18.561000  17.510    30     18.843333  17.670
# 2009-10-06 02:00:00    30    16.280667  13.755    30     16.547333  14.015
# 2009-10-06 02:30:00    30    23.389667  20.985    30     23.728333  21.160
# 2009-10-06 03:00:00    30    17.013333   9.680    30     17.383667  10.015
# 2009-10-06 03:30:00    30    15.282333  14.785    30     15.490333  15.125
# ...

# %%
resampled.describe
# Out:
# <bound method NDFrame.describe of                      Open                       High                        \
#                     count         mean  median count          mean  median
# date
# 2009-10-06 00:00:00    30    22.466333  18.595    30     22.828333  18.765
# 2009-10-06 00:30:00    30    21.765000   9.175    30     22.266333   9.325
# 2009-10-06 01:00:00    30    21.235000  17.450    30     21.637000  17.685
# 2009-10-06 01:30:00    30    18.561000  17.510    30     18.843333  17.670
# 2009-10-06 02:00:00    30    16.280667  13.755    30     16.547333  14.015
# 2009-10-06 02:30:00    30    23.389667  20.985    30     23.728333  21.160
# 2009-10-06 03:00:00    30    17.013333   9.680    30     17.383667  10.015
# 2009-10-06 03:30:00    30    15.282333  14.785    30     15.490333  15.125
# 2009-10-06 04:00:00    30    19.133000  22.200    30     19.396667  22.495
# 2009-10-06 04:30:00    30    28.436667  20.270    30     28.852333  20.445
# ...

# %% [markdown]
# ### Timestamp vs timespans

# %%
pd.Period('2012', freq='A-DEC')
# Out:
# Period('2012', 'A-DEC')

# %%
pd.Period('2012-1-1', freq='D')
# Out:
# Period('2012-01-01', 'D')

# %%
 pd.Period('2012-1-1 19:00', freq='H')
# Out:
# Period('2012-01-01 19:00', 'H')

# %%
pd.Period('2012-1-1 19:00', freq='5H')
# Out:
# Period('2012-01-01 19:00', '5H')

# %%
p = pd.Period('2012', freq='A-DEC')
p
# Out:
# Period('2012', 'A-DEC')

# %%
p + 1
# Out:
# Period('2013', 'A-DEC')

# %%
p - 3
# Out:
# Period('2009', 'A-DEC')

# %%
p+1
# Out:
# Period('2013', 'A-DEC')

# %%
p - 2
# Out:
# Period('2014-07-01 07:00', 'H')

# %%
p = pd.Period('2014-07-01 09:00', freq='H')

# %%
 prng = pd.period_range('1/1/2011', '1/1/2012', freq='M')
prng
# Out:
# PeriodIndex(['2011-01', '2011-02', '2011-03', '2011-04', '2011-05', '2011-06',
#              '2011-07', '2011-08', '2011-09', '2011-10', '2011-11', '2011-12',
#              '2012-01'],
#             dtype='int64', freq='M')

# %%
pd.PeriodIndex(['2011-1', '2011-2', '2011-3'], freq='M')
# Out:
# PeriodIndex(['2011-01', '2011-02', '2011-03'], dtype='int64', freq='M')

# %%
pd.PeriodIndex(start='2014-01', freq='3M', periods=4)
# Out:
# PeriodIndex(['2014-01', '2014-04', '2014-07', '2014-10'], dtype='int64', freq='3M')

# %%
idx = pd.period_range('2014-07-01 09:00', periods=5, freq='H')
idx
# Out:
# PeriodIndex(['2014-07-01 09:00', '2014-07-01 10:00', '2014-07-01 11:00',
#              '2014-07-01 12:00', '2014-07-01 13:00'],
#             dtype='int64', freq='H')
